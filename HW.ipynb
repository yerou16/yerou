# %%
import pandas as pd

# 設定 CSV 檔案的路徑
csv_file_path_2022 = '2022.csv'
csv_file_path_2023 = '2023.csv'

print("CSV文件路径 2022:", csv_file_path_2022)
print("CSV文件路径 2023:", csv_file_path_2023)

# 使用 pandas 的 read_csv 函式讀取 CSV 檔案並將其轉換為 DataFrame
df_2022 = pd.read_csv(csv_file_path_2022)
df_2023 = pd.read_csv(csv_file_path_2023)

print(df_2022)
print(df_2023)
# Out:
# CSV文件路径 2022: 2022.csv
# CSV文件路径 2023: 2023.csv
#       排名                  語言        語系          分支     母語 (L1) 人數  \
# 0    1.0                  英語      印歐語系       日耳曼語族  372.9 million
# 1    2.0                  官話      漢藏語系         漢語族  929.0 million
# 2    NaN     （包有標準官話，排丟中國方言）       NaN         NaN            NaN
# 3    3.0                 印地文      印歐語系    印度-雅利安語支  343.9 million
# 4    NaN             （排丟烏都文）       NaN         NaN            NaN
# 5    4.0                西班牙語      印歐語系        羅曼語族  474.7 million
# 6    5.0                  法語      印歐語系        羅曼語族   79.9 million
# 7    6.0              標準阿拉伯語      亞非語系         閃語族           0[a]
# 8    NaN              （排丟方言）       NaN         NaN            NaN
# 9    7.0                孟加拉語      印歐語系    印度-雅利安語支  233.7 million
# 10   8.0                  俄語      印歐語系   波羅的-斯拉夫語族  154.0 million
# 11   9.0                葡萄牙語      印歐語系        羅曼語族  232.4 million
# ...

# %%
# 從 DataFrame 中取出語言欄位，假設欄位名稱為 '語言'，你可以根據實際情況調整
language_names_2022 = df_2022['語言']
language_names_2023 = df_2023['語言']


# 將語言轉換為 set 資料型態
language_names_2022_set = set(language_names_2022)
language_names_2023_set = set(language_names_2023)

#最多國家使用的語言和最多人口數使用的語言是那些語言
print(language_names_2022_set)
print(language_names_2023_set)
print(language_names_2022_set & language_names_2023_set)
# Out:
# {'菩闍補里語', '伊朗波斯語', '卡納達語', '馬拉提語', '（包有上海話）', '（包有標準官話，排丟中國方言）', '埃及阿拉伯語', '爪哇語', '東頻渣別語', '斯華希里語', '（包有廣府話）', '緬甸語', '英語', '（排丟西頻渣別文）', '泰盧固語', '標準阿拉伯語', '吳語', '阿姆哈拉語', '客家語', '土耳其語', '日語', '他加祿語', '越南語', '法語', '西班牙語', '葡萄牙語', '（排丟其他阿拉伯文方言）', '（排丟達利文同塔吉克文）', '尼日利亞歸融語', '韓語', '印地文', '（排丟印地文）', '西頻渣別文', '晉語', '波蘭語', '阿爾及利亞口語阿拉伯語', '印尼語', '古乍拉地語', '閩南語', '（排丟馬來文）', '粵語', '（排丟東頻渣別文）', '（排丟方言）', '優魯巴語', '（包有泉漳福建話（hokkien））', '孟加拉語', '德語', '蘇丹口語阿拉伯語', '泰語', '豪薩語', '林加拉語', '（排丟烏都文）', '俄語', '意大利語', '官話', '淡米爾語', '烏都語'}
# {'札那語', '荷蘭語', '阿拉伯語', '艾馬拉語', '漢語', '文達語', '索馬利亞語', '塞爾維亞-克羅埃西亞語', '柏柏語', '阿爾巴尼亞語', '史瓦帝語', '英語', '克丘亞語', '印度斯坦語', '土耳其語', '斯瓦希里語', '塞索托語', '法語', '西班牙語', '波斯語', '葡萄牙語', '義大利語', '希臘語', '瑞典語', '韓語', '坦米爾語', '提格利尼亞語', '科薩語', '羅馬尼亞語', '亞美尼亞語', '馬來語', '盧安達-基隆迪語', '德語', '齊切瓦語', '俄語', '瓜拉尼語'}
# {'韓語', '德語', '土耳其語', '法語', '俄語', '葡萄牙語', '西班牙語', '英語'}
